# %% [markdown]
# https://stepik.org/lesson/969707/step/14
#
# # На вход поступает последовательность из чисел 0 и 1, разделенных пробелом. Создать на ее основе объект Series, содержащий булевы значения True (1), False (0) c метками [a, b, c, d,...]. Гарантируется что длина последовательности менее 26. Также учтите, что длина - последовательности переменная величина.

# %%
import pandas as pd
from string import ascii_lowercase

# x = '1 0 1 0 0 1'

s = pd.Series([int(x) for x in input().split()], dtype=bool)
s.index = list(ascii_lowercase[:len(s)])
print(s)
# Out:
# 1 0 1 0 0 1
# a     True
# b    False
# c     True
# d    False
# e    False
# f     True
# dtype: bool

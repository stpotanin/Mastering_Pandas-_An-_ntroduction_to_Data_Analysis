# %% [markdown]
# https://stepik.org/lesson/969707/step/12
#
# # В первой строке поступает строка с символами разлепленными пробелом, во второй строка с целыми числами. На их основе создать список кортежей и из него объект Series, вывести его на печать.

# %%
import pandas as pd

# x = 'a b c'
# y = '4 6 2'

print(pd.Series(zip(input().split(), input().split())))
# Out:
# a b c
# 4 6 2
# 0    (a, 4)
# 1    (b, 6)
# 2    (c, 2)
# dtype: object

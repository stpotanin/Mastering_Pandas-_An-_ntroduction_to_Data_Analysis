# %% [markdown]
# https://stepik.org/lesson/969742/step/10

# %%
import pandas as pd

date, price = input().split(), input().split()
df = pd.Series([int(x) for x in price], date)

print(df[input().split()])
# Out:
# Alaska California Connecticut
# Alaska           731545
# California     39538223
# Connecticut     3605944
# dtype: int64

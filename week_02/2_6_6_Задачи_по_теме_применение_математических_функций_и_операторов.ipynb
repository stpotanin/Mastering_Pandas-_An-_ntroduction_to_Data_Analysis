# %% [markdown]
# https://stepik.org/lesson/971431/step/6
#
# # Создайте pd.Series, содержащий значения 1, 2, 3. Примените к каждому элементу функцию квадрата и сохраните результат в новый pd.Series. Обе Series распечатайте.

# %%
import pandas as pd

a = pd.Series([1, 2, 3])
print(a)

b = a**2
print(b)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64
# 0    1
# 1    4
# 2    9
# dtype: int64

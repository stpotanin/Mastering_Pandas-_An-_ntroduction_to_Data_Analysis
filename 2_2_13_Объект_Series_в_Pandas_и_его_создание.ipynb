# %% [markdown]
# https://stepik.org/lesson/969707/step/13
#
# # На вход поступает строка слов, разделенных пробелом. Создать на ее основе объект Series с метками 0, 1, 2,... Вывести его на печать.

# %%
import pandas as pd

# x = 'banana ananasa mandarina apelsina'

print(pd.Series(input().split()))
# Out:
# banana ananasa mandarina apelsina
# 0       banana
# 1      ananasa
# 2    mandarina
# 3     apelsina
# dtype: object
